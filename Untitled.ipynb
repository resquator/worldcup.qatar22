# %%
import requests
import pandas as pd
from tqdm import tqdm


from datetime import datetime
import logging
dateTimeObj = datetime.now()
timestampStr = dateTimeObj.strftime("%Y%m%d%H%M%S")
logging.basicConfig(filename=f'estimate_1N2_{timestampStr}.log',  level=logging.DEBUG,
    format='%(asctime)s %(message)s', datefmt='%m/%d/%Y %I:%M:%S %p')
timestampStr
# Out:
# '20221104182644'

# %%
FILE = 'dataset/training_dataset.csv'
df = pd.read_csv(FILE, parse_dates=['matchday'])

# %%
df
# Out:
#       Unnamed: 0   matchday       home_team     away_team  season competition  \
# 0              0 2002-05-31          France       Senegal    2002   world-cup
# 1              1 2002-06-01         Uruguay       Denmark    2002   world-cup
# 2              2 2002-06-01         Ireland      Cameroon    2002   world-cup
# 3              3 2002-06-01         Germany  Saudi Arabia    2002   world-cup
# 4              4 2002-06-02           Spain      Slovenia    2002   world-cup
# ...          ...        ...             ...           ...     ...         ...
# 4366        4366 2021-07-03  Czech Republic       Denmark    2020        euro
# 4367        4367 2021-07-03         Ukraine       England    2020        euro
# 4368        4368 2021-07-06           Italy         Spain    2020        euro
# 4369        4369 2021-07-07         England       Denmark    2020        euro
# 4370        4370 2021-07-11           Italy       England    2020        euro
#
# ...

# %%
cote=[]

field = '1N2_2'
cote.append([np.mean(df.query('home_team == "Argentina" and away_team == "France"')[field]),1.5])
cote.append([np.mean(df.query('home_team == "France" and away_team == "Argentina"')[field]),1.5])
cote.append([np.mean(df.query('home_team == "France" and target == 1')[field]),1.1])
cote.append([np.mean(df.query('home_team == "France" and target == 2')[field]),0.47])
cote.append([np.mean(df.query('home_team == "Argentina" and target == 2')[field]),0.47])
cote.append([np.mean(df.query('home_team == "Argentina" and target == 1')[field]),1.1])

temp=pd.DataFrame(cote).dropna()
temp.columns = ['COTE','FACTOR']
temp['RETURN']=temp.COTE * temp.FACTOR / 6
temp.RETURN.sum()
# Out:
# 4.123659901960784

# %%
df.query('home_team == "France" and away_team == "Argentina"')
# Out:
#       Unnamed: 0   matchday home_team  away_team  season  \
# 515          515 2007-02-07    France  Argentina    2007
# 1053        1053 2009-02-11    France  Argentina    2009
# 3677        3677 2018-06-30    France  Argentina    2018
#
#                  competition correct_score  1N2_1  1N2_N  1N2_2  \
# 515   friendly-international           0:1   2.19   3.07   3.09
# 1053  friendly-international           0:2   2.67   3.08   2.67
# 3677               world-cup           4:3   2.41   3.09   3.35
#
#       home_team_rank_FIFA  away_team_rank_FIFA  home_team_trend  \
# 515              4.500000             2.166667              7.0
# 1053             9.583333             6.916667              7.0
# 3677             4.833333             7.666667              9.0
#
#       away_team_trend  home_team_odd_trend  away_team_odd_trend  target  \
# 515              10.0               2.7975               2.5625     2.0
# ...
